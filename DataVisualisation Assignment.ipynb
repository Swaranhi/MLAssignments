# %% [markdown]
# # Data Visualisation Assignment

# %% [markdown]
# <b>In this assignment students have to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each data point with specific class.<b>

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D 
from sklearn import decomposition 
from sklearn import datasets 
import seaborn as sns
from sklearn.decomposition import PCA
import pandas as pd

# %%
iris_data=sns.load_dataset('iris')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
pca = PCA(n_components=3)
pca_result = pca.fit_transform(iris_data.iloc[:,0:4])

# %%
df=pd.DataFrame(pca_result,columns=['p1','p2','p3'])

# %%
df
# Out:
#            p1        p2        p3
# 0   -2.684126  0.319397 -0.027915
# 1   -2.714142 -0.177001 -0.210464
# 2   -2.888991 -0.144949  0.017900
# 3   -2.745343 -0.318299  0.031559
# 4   -2.728717  0.326755  0.090079
# ..        ...       ...       ...
# 145  1.944110  0.187532  0.177825
# 146  1.527167 -0.375317 -0.121898
# 147  1.764346  0.078859  0.130482
# 148  1.900942  0.116628  0.723252
# 149  1.390189 -0.282661  0.362910
#
# [150 rows x 3 columns]

# %%
fig = plt.figure(figsize = (15,15))
ax = plt.axes(projection='3d')
species = ['setosa', 'versicolor', 'virginica']
colors = ['r', 'g', 'b']
for spc,colour in zip(species,colors):
    i=iris_data['species']==spc
    ax.scatter(
    df.loc[i,"p1"], 
    df.loc[i,"p2"], 
    df.loc[i,"p3"], 
    s=50,c=colour
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
ax.legend(species)
plt.show()
